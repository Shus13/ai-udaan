# %%
import pandas as pd

# %%
result = pd.Series(["japan", "usa", "nepal"])
print(result)
# Out:
# 0    japan
# 1      usa
# 2    nepal
# dtype: str

# %%
num = pd.Series([10,20,30,40], index=["ek", "deu", "tin", "char"])
print(num)
# Out:
# ek      10
# deu     20
# tin     30
# char    40
# dtype: int64

# %%
student_data = ({
    "name" : ["sushit", "ram", "shyam"],
    "age" : [22, 23, 24],
    "course" : ["MERN", "AI/ML", "Figma"]
})
student_dataframe = pd.DataFrame(student_data)
print(student_dataframe)
# Out:
#      name  age course
# 0  sushit   22   MERN
# 1     ram   23  AI/ML
# 2   shyam   24  Figma

# %%
stud_data = pd.read_csv("dataset/student-data.csv")
print(stud_data)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
stud_excel = pd.read_excel("dataset/datasets.xlsx")
print(stud_excel)
# Out:
#     Dataset Id                                           Web Page  \
# 0        29d00  https://data.brent.gov.uk/dataset/2001-census-...
# 1        ep1kd  https://data.brent.gov.uk/dataset/2011-census-...
# 2        2j15j  https://data.brent.gov.uk/dataset/2001-to-2011...
# 3        20k5k  https://data.brent.gov.uk/dataset/2001-to-2011...
# 4        2nkny  https://data.brent.gov.uk/dataset/2001-to-2011...
# ..         ...                                                ...
# 304      epzqg  https://data.brent.gov.uk/dataset/provider-sel...
# 305      e7j0m  https://data.brent.gov.uk/dataset/children-and...
# 306      2n64m  https://data.brent.gov.uk/dataset/ward-profile...
# 307      vqod7  https://data.brent.gov.uk/dataset/planning-dat...
# 308      v80k3  https://data.brent.gov.uk/dataset/cancer-needs...
#
#                                                  Title  \
# 0                           2001 Census Key Statistics
# 1                              2011 Census Definitions
# ...

# %%
json_data = pd.read_json("dataset/airports.json")
print(json_data)
# Out:
#                                              airports
# 0   {'code': 'ATL', 'name': 'Hartsfield-Jackson At...
# 1   {'code': 'PEK', 'name': 'Beijing Capital Inter...
# 2   {'code': 'DXB', 'name': 'Dubai International',...
# 3   {'code': 'LAX', 'name': 'Los Angeles Internati...
# 4   {'code': 'HND', 'name': 'Tokyo Haneda', 'city'...
# 5   {'code': 'ORD', 'name': 'O'Hare International'...
# 6   {'code': 'LHR', 'name': 'London Heathrow', 'ci...
# 7   {'code': 'PVG', 'name': 'Shanghai Pudong Inter...
# 8   {'code': 'CDG', 'name': 'Paris Charles de Gaul...
# 9   {'code': 'DFW', 'name': 'Dallas/Fort Worth Int...
# 10  {'code': 'CAN', 'name': 'Guangzhou Baiyun Inte...
# 11  {'code': 'AMS', 'name': 'Amsterdam Schiphol', ...
# 12  {'code': 'FRA', 'name': 'Frankfurt Airport', '...
# 13  {'code': 'IST', 'name': 'Istanbul Airport', 'c...
# 14  {'code': 'SIN', 'name': 'Singapore Changi', 'c...
# 15  {'code': 'ICN', 'name': 'Incheon International...
# ...
